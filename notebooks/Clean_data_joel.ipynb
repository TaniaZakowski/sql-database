# %%
import pandas as pd

# %%
df = pd.read_csv('Mini_project/goal15.forest_shares.csv')

df
# Out:
#     iso3c  forests_2000  forests_2020  trend
# 0     AFG           1.9           1.9    0.0
# 1     ALB          28.1          28.8    2.5
# 2     DZA           0.7           0.8   14.3
# 3     ASM          88.7          85.7   -3.4
# 4     AND          34.0          34.0    0.0
# ..    ...           ...           ...    ...
# 232   ESH           2.5           2.5    0.0
# 233   WLD          31.9          31.2   -2.2
# 234   YEM           1.0           1.0    0.0
# 235   ZMB          63.3          60.3   -4.7
# 236   ZWE          47.5          45.1   -5.1
#
# [237 rows x 4 columns]

# %%
df.isnull()
# Out:
#      iso3c  forests_2000  forests_2020  trend
# 0    False         False         False  False
# 1    False         False         False  False
# 2    False         False         False  False
# 3    False         False         False  False
# 4    False         False         False  False
# ..     ...           ...           ...    ...
# 232  False         False         False  False
# 233  False         False         False  False
# 234  False         False         False  False
# 235  False         False         False  False
# 236  False         False         False  False
#
# [237 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# iso3c            0
# forests_2000     0
# forests_2020     0
# trend           10
# dtype: int64

# %%
df.rename(columns={'iso3c': 'country_code'}, inplace=True)

# %%
df.dropna(how='all', inplace=True)

# %%
df
# Out:
#     country_code  forests_2000  forests_2020  trend
# 0            AFG           1.9           1.9    0.0
# 1            ALB          28.1          28.8    2.5
# 2            DZA           0.7           0.8   14.3
# 3            ASM          88.7          85.7   -3.4
# 4            AND          34.0          34.0    0.0
# ..           ...           ...           ...    ...
# 232          ESH           2.5           2.5    0.0
# 233          WLD          31.9          31.2   -2.2
# 234          YEM           1.0           1.0    0.0
# 235          ZMB          63.3          60.3   -4.7
# 236          ZWE          47.5          45.1   -5.1
#
# [237 rows x 4 columns]

# %%
df.isna ()
# Out:
#      country_code  forests_2000  forests_2020  trend
# 0           False         False         False  False
# 1           False         False         False  False
# 2           False         False         False  False
# 3           False         False         False  False
# 4           False         False         False  False
# ..            ...           ...           ...    ...
# 232         False         False         False  False
# 233         False         False         False  False
# 234         False         False         False  False
# 235         False         False         False  False
# 236         False         False         False  False
#
# [237 rows x 4 columns]

# %%
df.rename(columns={'forests_2000': 'forests_2000_(%)', 'forests_2020': 'forests_2020_(%)', 'trend': 'trend_(%)'}, inplace=True)

# %%
df
# Out:
#     country_code  forests_2000_(%)  forests_2020_(%)  trend_(%)
# 0            AFG               1.9               1.9        0.0
# 1            ALB              28.1              28.8        2.5
# 2            DZA               0.7               0.8       14.3
# 3            ASM              88.7              85.7       -3.4
# 4            AND              34.0              34.0        0.0
# ..           ...               ...               ...        ...
# 232          ESH               2.5               2.5        0.0
# 233          WLD              31.9              31.2       -2.2
# 234          YEM               1.0               1.0        0.0
# 235          ZMB              63.3              60.3       -4.7
# 236          ZWE              47.5              45.1       -5.1
#
# [237 rows x 4 columns]

# %%
df.rename(columns = {'trend_(%)' : 'percentage_change'}, inplace = True)

# %%
df
# Out:
#     country_code  forests_2000_(%)  forests_2020_(%)  percentage_change
# 0            AFG               1.9               1.9                0.0
# 1            ALB              28.1              28.8                2.5
# 2            DZA               0.7               0.8               14.3
# 3            ASM              88.7              85.7               -3.4
# 4            AND              34.0              34.0                0.0
# ..           ...               ...               ...                ...
# 232          ESH               2.5               2.5                0.0
# 233          WLD              31.9              31.2               -2.2
# 234          YEM               1.0               1.0                0.0
# 235          ZMB              63.3              60.3               -4.7
# 236          ZWE              47.5              45.1               -5.1
#
# [237 rows x 4 columns]

# %%
df.dropna(how='any', inplace=True)

# %%
df.head (50)
# Out:
#    country_code  forests_2000_(%)  forests_2020_(%)  percentage_change
# 0           AFG               1.9               1.9                0.0
# 1           ALB              28.1              28.8                2.5
# 2           DZA               0.7               0.8               14.3
# 3           ASM              88.7              85.7               -3.4
# 4           AND              34.0              34.0                0.0
# 5           AGO              62.3              53.4              -14.3
# 6           AIA              61.1              61.1                0.0
# 7           ATG              21.5              18.5              -14.0
# 8           ARG              12.2              10.4              -14.8
# 9           ARM              11.7              11.5               -1.7
# 10          ABW               2.3               2.3                0.0
# 11          AUS              17.2              17.4                1.2
# ...

# %%
df
# Out:
#     country_code  forests_2000_(%)  forests_2020_(%)  percentage_change
# 0            AFG               1.9               1.9                0.0
# 1            ALB              28.1              28.8                2.5
# 2            DZA               0.7               0.8               14.3
# 3            ASM              88.7              85.7               -3.4
# 4            AND              34.0              34.0                0.0
# ..           ...               ...               ...                ...
# 232          ESH               2.5               2.5                0.0
# 233          WLD              31.9              31.2               -2.2
# 234          YEM               1.0               1.0                0.0
# 235          ZMB              63.3              60.3               -4.7
# 236          ZWE              47.5              45.1               -5.1
#
# [227 rows x 4 columns]

# %%
df.to_csv('cleaned_data.csv', index=False)
