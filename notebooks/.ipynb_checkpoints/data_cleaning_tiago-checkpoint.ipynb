# %%
import pandas as pd
import functions as func
import yaml

try:
    with open("../config.yaml", "r") as file:
        config = yaml.safe_load(file)
except:
    print("The config.yaml file was not found in the main folder!")

df = pd.read_csv(config['data_raw']['file3'])

df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
df = df.drop(["Country Name","Indicator Name","Indicator Code","Unnamed: 68"],axis=1)
df
# Out:
#     Country Code         1960         1961         1962         1963  \
# 0            ABW      54608.0      55811.0      56682.0      57475.0
# 1            AFE  130692579.0  134169237.0  137835590.0  141630546.0
# 2            AFG    8622466.0    8790140.0    8969047.0    9157465.0
# 3            AFW   97256290.0   99314028.0  101445032.0  103667517.0
# 4            AGO    5357195.0    5441333.0    5521400.0    5599827.0
# ..           ...          ...          ...          ...          ...
# 261          XKX     990150.0    1014211.0    1038618.0    1063175.0
# 262          YEM    5542459.0    5646668.0    5753386.0    5860197.0
# 263          ZAF   16520441.0   16989464.0   17503133.0   18042215.0
# 264          ZMB    3119430.0    3219451.0    3323427.0    3431381.0
# 265          ZWE    3806310.0    3925952.0    4049778.0    4177931.0
#
#             1964         1965         1966         1967         1968  ...  \
# ...
